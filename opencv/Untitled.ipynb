# %%
import cv2
from cv2 import face_BasicFaceRecognizer
import numpy as np
from matplotlib import pyplot as plt

# %%
# 이미지 불러오기
image = cv2.imread('imgs/image.png')
# 흑백이미지 만들기
grayImage = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
# 흑백이미지 그리기
plt.figure(figsize=(12,8))
plt.imshow(grayImage, cmap='gray')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
faces = face_cascade.detectMultiScale(grayImage, 1.03, 5)
print(faces.shape)
print("얼굴 개수: " + str(faces.shape[0]))
faces
# Out:
# (1, 4)
# 얼굴 개수: 1
# array([[103,  79, 116, 116]], dtype=int32)

# %%
for (x,y,w,h) in faces:
    cv2.rectangle(grayImage,(x,y),(x+w,y+h),(255,0,0),2)
plt.figure(figsize=(12,12))
plt.imshow(grayImage, cmap='gray')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()

# %%
for (x,y,w,h) in faces:
    cv2.rectangle(grayImage,(x,y),(x+w,y+h),(255,0,0),2)
    cropped = grayImage[y - int(h/4):y + h + int(h/4), x - int(w/4):x + w + int(w/4)]
plt.figure(figsize=(12,12))
plt.imshow(cropped, cmap='gray')
plt.xticks([]), plt.yticks([])
plt.show()
