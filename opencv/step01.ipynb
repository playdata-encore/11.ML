# %%
import matplotlib.pyplot as plt
import cv2

# %%
print(cv2.__version__)
# Out:
# 4.5.1

# %%
img = cv2.imread('imgs/cat.bmp')

#영상이 없을 수도 있다는 전제하에 조건문 적용 권장
if img is None:
    sys.exit()

img = cv2.resize(img, (200,300))

cv2.imshow('cat image', img)

#생략시 안보임, key 입력될 때까지 이밎 ㅗ하면에 실행 해 놓겠다는 의미
cv2.waitKey()

cv2.destroyAllWindows()

# %%
img2 = cv2.imwrite('imgs/cat2.bmp', img)
img2
# Out:
# True

# %%
imgBGR = cv2.imread('imgs/cat.bmp')
imgRGB = cv2.cvtColor(imgBGR, cv2.COLOR_BGR2RGB)
plt.axis('off')
plt.imshow(imgRGB)
plt.show()

# %%
imgBGR = cv2.imread('imgs/cat.bmp')
imgRGB = cv2.cvtColor(imgBGR, cv2.COLOR_RGB2BGR)
plt.axis('off')
plt.imshow(imgRGB)
plt.show()

# %%
# 그레이스케일 영상 출력
imgGray = cv2.imread('imgs/cat.bmp', cv2.IMREAD_GRAYSCALE)
# plt.axis('off')
plt.imshow(imgGray, cmap='gray')
plt.show()
# 두 개의 영상을 함께 출력
plt.subplot(121), plt.axis('off'), plt.imshow(imgRGB)
plt.subplot(122), plt.axis('off'), plt.imshow(imgGray, cmap='gray')
plt.show()

# %% [markdown]
# 4. 영상(이미지 & 동영상)의 속성과 픽셀값 참조

# %%
img1 = cv2.imread('imgs/cat.bmp', cv2.IMREAD_GRAYSCALE)
img2 = cv2.imread('imgs/cat.bmp', cv2.IMREAD_COLOR)

if img1 is None or img2 is None:
    sys.exit()

# 이미지는 numpy 즉 ndarray 행렬 형식
print(type(img1), img1.shape, img1.dtype)

print(type(img1), img1.shape, img1.dtype)
# Out:
# <class 'numpy.ndarray'> (480, 640) uint8
# <class 'numpy.ndarray'> (480, 640) uint8

# %% [markdown]
# 5. ROI 부분 영상 추출 의미

# %%
img = cv2.imread('imgs/cat.bmp')

img2 = img[8:160,50:170]

cv2.imshow('img2',img2)

cv2.waitKey()
cv2.destroyAllWindows()
